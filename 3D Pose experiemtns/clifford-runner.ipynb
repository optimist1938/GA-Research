# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
GITHUB_TOKEN = user_secrets.get_secret("github_token")
USER = "git"
CLONE_URL = f"https://{USER}:{GITHUB_TOKEN}@github.com/optimist1938/GA-Research.git"
wandb_api_key = user_secrets.get_secret("wandb_api_key")
# github.com:optimist1938/GA-Research.git
get_ipython().system(f"git clone -b main {CLONE_URL}")

# %%
# !pip install poetry --quiet \
    && cd ./GA-Research/3D\ Pose\ experiemtns/ \
    && poetry -q install \
    && poetry run python src/main.py \
    --path_to_datasets="/kaggle/input/pascal3d" \
    --n_epochs=10 \
    --batch_size=32
